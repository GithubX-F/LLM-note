# %%
import os
import sentencepiece as spm
# from transformers import LlamaTokenizer
from transformers import AutoTokenizer
from sentencepiece import sentencepiece_model_pb2 as sp_pb2_model

# https://www.cnblogs.com/wangzhilun/p/17727243.html

# %%
# 1. 训练新的中文 BPE 词表
spm.SentencePieceTrainer.train(
    input='./news-commentary-v13-zh-en.txt',  # 输入的中文语料文件
    input_format='text',
    model_prefix='chinese_bpe',  # 输出的模型文件前缀
    model_type='bpe',  # 使用 BPE 算法
    vocab_size=10000,  # 生成的词表大小
    character_coverage=0.9995,  # 字符覆盖率
    num_threads=40,  # 训练线程数
    split_digits=True,  # 是否分割数字
    byte_fallback=True,  # 是否启用字节回退
    max_sentence_length=24000  # 最大句子长度
)
# Out:
# sentencepiece_trainer.cc(78) LOG(INFO) Starts training with :
# trainer_spec {
#   input: ./news-commentary-v13-zh-en.txt
#   input_format: text
#   model_prefix: chinese_bpe
#   model_type: BPE
#   vocab_size: 10000
#   self_test_sample_size: 0
#   character_coverage: 0.9995
#   input_sentence_size: 0
#   shuffle_input_sentence: 1
#   seed_sentencepiece_size: 1000000
#   shrinking_factor: 0.75
#   max_sentence_length: 24000
#   num_threads: 40
#   num_sub_iterations: 2
#   max_sentencepiece_length: 16
#   split_by_unicode_script: 1
#   split_by_number: 1
#   split_by_whitespace: 1
#   split_digits: 1
#   pretokenization_delimiter:
#   treat_whitespace_as_suffix: 0
#   allow_whitespace_only_pieces: 0
#   required_chars:
#   byte_fallback: 1
#   vocabulary_output_piece_score: 1
#   train_extremely_large_corpus: 0
#   seed_sentencepieces_file:
#   hard_vocab_limit: 1
#   use_all_vocab: 0
#   unk_id: 0
#   bos_id: 1
#   eos_id: 2
#   pad_id: -1
#   unk_piece: <unk>
#   bos_piece: <s>
#   eos_piece: </s>
#   pad_piece: <pad>
#   unk_surface:  ⁇
#   enable_differential_privacy: 0
#   differential_privacy_noise_level: 0
#   differential_privacy_clipping_threshold: 0
# }
# normalizer_spec {
#   name: nmt_nfkc
#   add_dummy_prefix: 1
#   remove_extra_whitespaces: 1
#   escape_whitespaces: 1
#   normalization_rule_tsv:
# }
# denormalizer_spec {}
# trainer_interface.cc(353) LOG(INFO) SentenceIterator is not specified. Using MultiFileSentenceIterator.
# trainer_interface.cc(185) LOG(INFO) Loading corpus: ./news-commentary-v13-zh-en.txt
# trainer_interface.cc(409) LOG(INFO) Loaded all 252777 sentences
# trainer_interface.cc(425) LOG(INFO) Adding meta_piece: <unk>
# trainer_interface.cc(425) LOG(INFO) Adding meta_piece: <s>
# trainer_interface.cc(425) LOG(INFO) Adding meta_piece: </s>
# trainer_interface.cc(425) LOG(INFO) Adding meta_piece: <0x00>
# trainer_interface.cc(425) LOG(INFO) Adding meta_piece: <0x01>
# trainer_interface.cc(425) LOG(INFO) Adding meta_piece: <0x02>
# trainer_interface.cc(425) LOG(INFO) Adding meta_piece: <0x03>
# trainer_interface.cc(425) LOG(INFO) Adding meta_piece: <0x04>
# trainer_interface.cc(425) LOG(INFO) Adding meta_piece: <0x05>
# trainer_interface.cc(425) LOG(INFO) Adding meta_piece: <0x06>
# trainer_interface.cc(425) LOG(INFO) Adding meta_piece: <0x07>
# trainer_interface.cc(425) LOG(INFO) Adding meta_piece: <0x08>
# trainer_interface.cc(425) LOG(INFO) Adding meta_piece: <0x09>
# trainer_interface.cc(425) LOG(INFO) Adding meta_piece: <0x0A>
# trainer_interface.cc(425) LOG(INFO) Adding meta_piece: <0x0B>
# trainer_interface.cc(425) LOG(INFO) Adding meta_piece: <0x0C>
# trainer_interface.cc(425) LOG(INFO) Adding meta_piece: <0x0D>
# trainer_interface.cc(425) LOG(INFO) Adding meta_piece: <0x0E>
# trainer_interface.cc(425) LOG(INFO) Adding meta_piece: <0x0F>
# trainer_interface.cc(425) LOG(INFO) Adding meta_piece: <0x10>
# trainer_interface.cc(425) LOG(INFO) Adding meta_piece: <0x11>
# trainer_interface.cc(425) LOG(INFO) Adding meta_piece: <0x12>
# trainer_interface.cc(425) LOG(INFO) Adding meta_piece: <0x13>
# trainer_interface.cc(425) LOG(INFO) Adding meta_piece: <0x14>
# trainer_interface.cc(425) LOG(INFO) Adding meta_piece: <0x15>
# trainer_interface.cc(425) LOG(INFO) Adding meta_piece: <0x16>
# trainer_interface.cc(425) LOG(INFO) Adding meta_piece: <0x17>
# trainer_interface.cc(425) LOG(INFO) Adding meta_piece: <0x18>
# trainer_interface.cc(425) LOG(INFO) Adding meta_piece: <0x19>
# trainer_interface.cc(425) LOG(INFO) Adding meta_piece: <0x1A>
# trainer_interface.cc(425) LOG(INFO) Adding meta_piece: <0x1B>
# trainer_interface.cc(425) LOG(INFO) Adding meta_piece: <0x1C>
# trainer_interface.cc(425) LOG(INFO) Adding meta_piece: <0x1D>
# trainer_interface.cc(425) LOG(INFO) Adding meta_piece: <0x1E>
# trainer_interface.cc(425) LOG(INFO) Adding meta_piece: <0x1F>
# trainer_interface.cc(425) LOG(INFO) Adding meta_piece: <0x20>
# trainer_interface.cc(425) LOG(INFO) Adding meta_piece: <0x21>
# trainer_interface.cc(425) LOG(INFO) Adding meta_piece: <0x22>
# trainer_interface.cc(425) LOG(INFO) Adding meta_piece: <0x23>
# trainer_interface.cc(425) LOG(INFO) Adding meta_piece: <0x24>
# trainer_interface.cc(425) LOG(INFO) Adding meta_piece: <0x25>
# trainer_interface.cc(425) LOG(INFO) Adding meta_piece: <0x26>
# trainer_interface.cc(425) LOG(INFO) Adding meta_piece: <0x27>
# trainer_interface.cc(425) LOG(INFO) Adding meta_piece: <0x28>
# trainer_interface.cc(425) LOG(INFO) Adding meta_piece: <0x29>
# trainer_interface.cc(425) LOG(INFO) Adding meta_piece: <0x2A>
# trainer_interface.cc(425) LOG(INFO) Adding meta_piece: <0x2B>
# trainer_interface.cc(425) LOG(INFO) Adding meta_piece: <0x2C>
# trainer_interface.cc(425) LOG(INFO) Adding meta_piece: <0x2D>
# trainer_interface.cc(425) LOG(INFO) Adding meta_piece: <0x2E>
# trainer_interface.cc(425) LOG(INFO) Adding meta_piece: <0x2F>
# trainer_interface.cc(425) LOG(INFO) Adding meta_piece: <0x30>
# trainer_interface.cc(425) LOG(INFO) Adding meta_piece: <0x31>
# trainer_interface.cc(425) LOG(INFO) Adding meta_piece: <0x32>
# trainer_interface.cc(425) LOG(INFO) Adding meta_piece: <0x33>
# trainer_interface.cc(425) LOG(INFO) Adding meta_piece: <0x34>
# trainer_interface.cc(425) LOG(INFO) Adding meta_piece: <0x35>
# trainer_interface.cc(425) LOG(INFO) Adding meta_piece: <0x36>
# trainer_interface.cc(425) LOG(INFO) Adding meta_piece: <0x37>
# trainer_interface.cc(425) LOG(INFO) Adding meta_piece: <0x38>
# trainer_interface.cc(425) LOG(INFO) Adding meta_piece: <0x39>
# trainer_interface.cc(425) LOG(INFO) Adding meta_piece: <0x3A>
# trainer_interface.cc(425) LOG(INFO) Adding meta_piece: <0x3B>
# trainer_interface.cc(425) LOG(INFO) Adding meta_piece: <0x3C>
# trainer_interface.cc(425) LOG(INFO) Adding meta_piece: <0x3D>
# trainer_interface.cc(425) LOG(INFO) Adding meta_piece: <0x3E>
# trainer_interface.cc(425) LOG(INFO) Adding meta_piece: <0x3F>
# trainer_interface.cc(425) LOG(INFO) Adding meta_piece: <0x40>
# trainer_interface.cc(425) LOG(INFO) Adding meta_piece: <0x41>
# trainer_interface.cc(425) LOG(INFO) Adding meta_piece: <0x42>
# trainer_interface.cc(425) LOG(INFO) Adding meta_piece: <0x43>
# trainer_interface.cc(425) LOG(INFO) Adding meta_piece: <0x44>
# trainer_interface.cc(425) LOG(INFO) Adding meta_piece: <0x45>
# trainer_interface.cc(425) LOG(INFO) Adding meta_piece: <0x46>
# trainer_interface.cc(425) LOG(INFO) Adding meta_piece: <0x47>
# trainer_interface.cc(425) LOG(INFO) Adding meta_piece: <0x48>
# trainer_interface.cc(425) LOG(INFO) Adding meta_piece: <0x49>
# trainer_interface.cc(425) LOG(INFO) Adding meta_piece: <0x4A>
# trainer_interface.cc(425) LOG(INFO) Adding meta_piece: <0x4B>
# trainer_interface.cc(425) LOG(INFO) Adding meta_piece: <0x4C>
# trainer_interface.cc(425) LOG(INFO) Adding meta_piece: <0x4D>
# trainer_interface.cc(425) LOG(INFO) Adding meta_piece: <0x4E>
# trainer_interface.cc(425) LOG(INFO) Adding meta_piece: <0x4F>
# trainer_interface.cc(425) LOG(INFO) Adding meta_piece: <0x50>
# trainer_interface.cc(425) LOG(INFO) Adding meta_piece: <0x51>
# trainer_interface.cc(425) LOG(INFO) Adding meta_piece: <0x52>
# trainer_interface.cc(425) LOG(INFO) Adding meta_piece: <0x53>
# trainer_interface.cc(425) LOG(INFO) Adding meta_piece: <0x54>
# trainer_interface.cc(425) LOG(INFO) Adding meta_piece: <0x55>
# trainer_interface.cc(425) LOG(INFO) Adding meta_piece: <0x56>
# trainer_interface.cc(425) LOG(INFO) Adding meta_piece: <0x57>
# trainer_interface.cc(425) LOG(INFO) Adding meta_piece: <0x58>
# trainer_interface.cc(425) LOG(INFO) Adding meta_piece: <0x59>
# trainer_interface.cc(425) LOG(INFO) Adding meta_piece: <0x5A>
# trainer_interface.cc(425) LOG(INFO) Adding meta_piece: <0x5B>
# trainer_interface.cc(425) LOG(INFO) Adding meta_piece: <0x5C>
# trainer_interface.cc(425) LOG(INFO) Adding meta_piece: <0x5D>
# trainer_interface.cc(425) LOG(INFO) Adding meta_piece: <0x5E>
# trainer_interface.cc(425) LOG(INFO) Adding meta_piece: <0x5F>
# trainer_interface.cc(425) LOG(INFO) Adding meta_piece: <0x60>
# trainer_interface.cc(425) LOG(INFO) Adding meta_piece: <0x61>
# trainer_interface.cc(425) LOG(INFO) Adding meta_piece: <0x62>
# trainer_interface.cc(425) LOG(INFO) Adding meta_piece: <0x63>
# trainer_interface.cc(425) LOG(INFO) Adding meta_piece: <0x64>
# trainer_interface.cc(425) LOG(INFO) Adding meta_piece: <0x65>
# trainer_interface.cc(425) LOG(INFO) Adding meta_piece: <0x66>
# trainer_interface.cc(425) LOG(INFO) Adding meta_piece: <0x67>
# trainer_interface.cc(425) LOG(INFO) Adding meta_piece: <0x68>
# trainer_interface.cc(425) LOG(INFO) Adding meta_piece: <0x69>
# trainer_interface.cc(425) LOG(INFO) Adding meta_piece: <0x6A>
# trainer_interface.cc(425) LOG(INFO) Adding meta_piece: <0x6B>
# trainer_interface.cc(425) LOG(INFO) Adding meta_piece: <0x6C>
# trainer_interface.cc(425) LOG(INFO) Adding meta_piece: <0x6D>
# trainer_interface.cc(425) LOG(INFO) Adding meta_piece: <0x6E>
# trainer_interface.cc(425) LOG(INFO) Adding meta_piece: <0x6F>
# trainer_interface.cc(425) LOG(INFO) Adding meta_piece: <0x70>
# trainer_interface.cc(425) LOG(INFO) Adding meta_piece: <0x71>
# trainer_interface.cc(425) LOG(INFO) Adding meta_piece: <0x72>
# trainer_interface.cc(425) LOG(INFO) Adding meta_piece: <0x73>
# trainer_interface.cc(425) LOG(INFO) Adding meta_piece: <0x74>
# trainer_interface.cc(425) LOG(INFO) Adding meta_piece: <0x75>
# trainer_interface.cc(425) LOG(INFO) Adding meta_piece: <0x76>
# trainer_interface.cc(425) LOG(INFO) Adding meta_piece: <0x77>
# trainer_interface.cc(425) LOG(INFO) Adding meta_piece: <0x78>
# trainer_interface.cc(425) LOG(INFO) Adding meta_piece: <0x79>
# trainer_interface.cc(425) LOG(INFO) Adding meta_piece: <0x7A>
# trainer_interface.cc(425) LOG(INFO) Adding meta_piece: <0x7B>
# trainer_interface.cc(425) LOG(INFO) Adding meta_piece: <0x7C>
# trainer_interface.cc(425) LOG(INFO) Adding meta_piece: <0x7D>
# trainer_interface.cc(425) LOG(INFO) Adding meta_piece: <0x7E>
# trainer_interface.cc(425) LOG(INFO) Adding meta_piece: <0x7F>
# trainer_interface.cc(425) LOG(INFO) Adding meta_piece: <0x80>
# trainer_interface.cc(425) LOG(INFO) Adding meta_piece: <0x81>
# trainer_interface.cc(425) LOG(INFO) Adding meta_piece: <0x82>
# trainer_interface.cc(425) LOG(INFO) Adding meta_piece: <0x83>
# trainer_interface.cc(425) LOG(INFO) Adding meta_piece: <0x84>
# trainer_interface.cc(425) LOG(INFO) Adding meta_piece: <0x85>
# trainer_interface.cc(425) LOG(INFO) Adding meta_piece: <0x86>
# trainer_interface.cc(425) LOG(INFO) Adding meta_piece: <0x87>
# trainer_interface.cc(425) LOG(INFO) Adding meta_piece: <0x88>
# trainer_interface.cc(425) LOG(INFO) Adding meta_piece: <0x89>
# trainer_interface.cc(425) LOG(INFO) Adding meta_piece: <0x8A>
# trainer_interface.cc(425) LOG(INFO) Adding meta_piece: <0x8B>
# trainer_interface.cc(425) LOG(INFO) Adding meta_piece: <0x8C>
# trainer_interface.cc(425) LOG(INFO) Adding meta_piece: <0x8D>
# trainer_interface.cc(425) LOG(INFO) Adding meta_piece: <0x8E>
# trainer_interface.cc(425) LOG(INFO) Adding meta_piece: <0x8F>
# trainer_interface.cc(425) LOG(INFO) Adding meta_piece: <0x90>
# trainer_interface.cc(425) LOG(INFO) Adding meta_piece: <0x91>
# trainer_interface.cc(425) LOG(INFO) Adding meta_piece: <0x92>
# trainer_interface.cc(425) LOG(INFO) Adding meta_piece: <0x93>
# trainer_interface.cc(425) LOG(INFO) Adding meta_piece: <0x94>
# trainer_interface.cc(425) LOG(INFO) Adding meta_piece: <0x95>
# trainer_interface.cc(425) LOG(INFO) Adding meta_piece: <0x96>
# trainer_interface.cc(425) LOG(INFO) Adding meta_piece: <0x97>
# trainer_interface.cc(425) LOG(INFO) Adding meta_piece: <0x98>
# trainer_interface.cc(425) LOG(INFO) Adding meta_piece: <0x99>
# trainer_interface.cc(425) LOG(INFO) Adding meta_piece: <0x9A>
# trainer_interface.cc(425) LOG(INFO) Adding meta_piece: <0x9B>
# trainer_interface.cc(425) LOG(INFO) Adding meta_piece: <0x9C>
# trainer_interface.cc(425) LOG(INFO) Adding meta_piece: <0x9D>
# trainer_interface.cc(425) LOG(INFO) Adding meta_piece: <0x9E>
# trainer_interface.cc(425) LOG(INFO) Adding meta_piece: <0x9F>
# trainer_interface.cc(425) LOG(INFO) Adding meta_piece: <0xA0>
# trainer_interface.cc(425) LOG(INFO) Adding meta_piece: <0xA1>
# trainer_interface.cc(425) LOG(INFO) Adding meta_piece: <0xA2>
# trainer_interface.cc(425) LOG(INFO) Adding meta_piece: <0xA3>
# trainer_interface.cc(425) LOG(INFO) Adding meta_piece: <0xA4>
# trainer_interface.cc(425) LOG(INFO) Adding meta_piece: <0xA5>
# trainer_interface.cc(425) LOG(INFO) Adding meta_piece: <0xA6>
# trainer_interface.cc(425) LOG(INFO) Adding meta_piece: <0xA7>
# trainer_interface.cc(425) LOG(INFO) Adding meta_piece: <0xA8>
# trainer_interface.cc(425) LOG(INFO) Adding meta_piece: <0xA9>
# trainer_interface.cc(425) LOG(INFO) Adding meta_piece: <0xAA>
# trainer_interface.cc(425) LOG(INFO) Adding meta_piece: <0xAB>
# trainer_interface.cc(425) LOG(INFO) Adding meta_piece: <0xAC>
# trainer_interface.cc(425) LOG(INFO) Adding meta_piece: <0xAD>
# trainer_interface.cc(425) LOG(INFO) Adding meta_piece: <0xAE>
# trainer_interface.cc(425) LOG(INFO) Adding meta_piece: <0xAF>
# trainer_interface.cc(425) LOG(INFO) Adding meta_piece: <0xB0>
# trainer_interface.cc(425) LOG(INFO) Adding meta_piece: <0xB1>
# trainer_interface.cc(425) LOG(INFO) Adding meta_piece: <0xB2>
# trainer_interface.cc(425) LOG(INFO) Adding meta_piece: <0xB3>
# trainer_interface.cc(425) LOG(INFO) Adding meta_piece: <0xB4>
# trainer_interface.cc(425) LOG(INFO) Adding meta_piece: <0xB5>
# trainer_interface.cc(425) LOG(INFO) Adding meta_piece: <0xB6>
# trainer_interface.cc(425) LOG(INFO) Adding meta_piece: <0xB7>
# trainer_interface.cc(425) LOG(INFO) Adding meta_piece: <0xB8>
# trainer_interface.cc(425) LOG(INFO) Adding meta_piece: <0xB9>
# trainer_interface.cc(425) LOG(INFO) Adding meta_piece: <0xBA>
# trainer_interface.cc(425) LOG(INFO) Adding meta_piece: <0xBB>
# trainer_interface.cc(425) LOG(INFO) Adding meta_piece: <0xBC>
# trainer_interface.cc(425) LOG(INFO) Adding meta_piece: <0xBD>
# trainer_interface.cc(425) LOG(INFO) Adding meta_piece: <0xBE>
# trainer_interface.cc(425) LOG(INFO) Adding meta_piece: <0xBF>
# trainer_interface.cc(425) LOG(INFO) Adding meta_piece: <0xC0>
# trainer_interface.cc(425) LOG(INFO) Adding meta_piece: <0xC1>
# trainer_interface.cc(425) LOG(INFO) Adding meta_piece: <0xC2>
# trainer_interface.cc(425) LOG(INFO) Adding meta_piece: <0xC3>
# trainer_interface.cc(425) LOG(INFO) Adding meta_piece: <0xC4>
# trainer_interface.cc(425) LOG(INFO) Adding meta_piece: <0xC5>
# trainer_interface.cc(425) LOG(INFO) Adding meta_piece: <0xC6>
# trainer_interface.cc(425) LOG(INFO) Adding meta_piece: <0xC7>
# trainer_interface.cc(425) LOG(INFO) Adding meta_piece: <0xC8>
# trainer_interface.cc(425) LOG(INFO) Adding meta_piece: <0xC9>
# trainer_interface.cc(425) LOG(INFO) Adding meta_piece: <0xCA>
# trainer_interface.cc(425) LOG(INFO) Adding meta_piece: <0xCB>
# trainer_interface.cc(425) LOG(INFO) Adding meta_piece: <0xCC>
# trainer_interface.cc(425) LOG(INFO) Adding meta_piece: <0xCD>
# trainer_interface.cc(425) LOG(INFO) Adding meta_piece: <0xCE>
# trainer_interface.cc(425) LOG(INFO) Adding meta_piece: <0xCF>
# trainer_interface.cc(425) LOG(INFO) Adding meta_piece: <0xD0>
# trainer_interface.cc(425) LOG(INFO) Adding meta_piece: <0xD1>
# trainer_interface.cc(425) LOG(INFO) Adding meta_piece: <0xD2>
# trainer_interface.cc(425) LOG(INFO) Adding meta_piece: <0xD3>
# trainer_interface.cc(425) LOG(INFO) Adding meta_piece: <0xD4>
# trainer_interface.cc(425) LOG(INFO) Adding meta_piece: <0xD5>
# trainer_interface.cc(425) LOG(INFO) Adding meta_piece: <0xD6>
# trainer_interface.cc(425) LOG(INFO) Adding meta_piece: <0xD7>
# trainer_interface.cc(425) LOG(INFO) Adding meta_piece: <0xD8>
# trainer_interface.cc(425) LOG(INFO) Adding meta_piece: <0xD9>
# trainer_interface.cc(425) LOG(INFO) Adding meta_piece: <0xDA>
# trainer_interface.cc(425) LOG(INFO) Adding meta_piece: <0xDB>
# trainer_interface.cc(425) LOG(INFO) Adding meta_piece: <0xDC>
# trainer_interface.cc(425) LOG(INFO) Adding meta_piece: <0xDD>
# trainer_interface.cc(425) LOG(INFO) Adding meta_piece: <0xDE>
# trainer_interface.cc(425) LOG(INFO) Adding meta_piece: <0xDF>
# trainer_interface.cc(425) LOG(INFO) Adding meta_piece: <0xE0>
# trainer_interface.cc(425) LOG(INFO) Adding meta_piece: <0xE1>
# trainer_interface.cc(425) LOG(INFO) Adding meta_piece: <0xE2>
# trainer_interface.cc(425) LOG(INFO) Adding meta_piece: <0xE3>
# trainer_interface.cc(425) LOG(INFO) Adding meta_piece: <0xE4>
# trainer_interface.cc(425) LOG(INFO) Adding meta_piece: <0xE5>
# trainer_interface.cc(425) LOG(INFO) Adding meta_piece: <0xE6>
# trainer_interface.cc(425) LOG(INFO) Adding meta_piece: <0xE7>
# trainer_interface.cc(425) LOG(INFO) Adding meta_piece: <0xE8>
# trainer_interface.cc(425) LOG(INFO) Adding meta_piece: <0xE9>
# trainer_interface.cc(425) LOG(INFO) Adding meta_piece: <0xEA>
# trainer_interface.cc(425) LOG(INFO) Adding meta_piece: <0xEB>
# trainer_interface.cc(425) LOG(INFO) Adding meta_piece: <0xEC>
# trainer_interface.cc(425) LOG(INFO) Adding meta_piece: <0xED>
# trainer_interface.cc(425) LOG(INFO) Adding meta_piece: <0xEE>
# trainer_interface.cc(425) LOG(INFO) Adding meta_piece: <0xEF>
# trainer_interface.cc(425) LOG(INFO) Adding meta_piece: <0xF0>
# trainer_interface.cc(425) LOG(INFO) Adding meta_piece: <0xF1>
# trainer_interface.cc(425) LOG(INFO) Adding meta_piece: <0xF2>
# trainer_interface.cc(425) LOG(INFO) Adding meta_piece: <0xF3>
# trainer_interface.cc(425) LOG(INFO) Adding meta_piece: <0xF4>
# trainer_interface.cc(425) LOG(INFO) Adding meta_piece: <0xF5>
# trainer_interface.cc(425) LOG(INFO) Adding meta_piece: <0xF6>
# trainer_interface.cc(425) LOG(INFO) Adding meta_piece: <0xF7>
# trainer_interface.cc(425) LOG(INFO) Adding meta_piece: <0xF8>
# trainer_interface.cc(425) LOG(INFO) Adding meta_piece: <0xF9>
# trainer_interface.cc(425) LOG(INFO) Adding meta_piece: <0xFA>
# trainer_interface.cc(425) LOG(INFO) Adding meta_piece: <0xFB>
# trainer_interface.cc(425) LOG(INFO) Adding meta_piece: <0xFC>
# trainer_interface.cc(425) LOG(INFO) Adding meta_piece: <0xFD>
# trainer_interface.cc(425) LOG(INFO) Adding meta_piece: <0xFE>
# trainer_interface.cc(425) LOG(INFO) Adding meta_piece: <0xFF>
# trainer_interface.cc(430) LOG(INFO) Normalizing sentences...
# trainer_interface.cc(539) LOG(INFO) all chars count=46076648
# trainer_interface.cc(550) LOG(INFO) Done: 99.95% characters are covered.
# trainer_interface.cc(560) LOG(INFO) Alphabet size=2617
# trainer_interface.cc(561) LOG(INFO) Final character coverage=0.9995
# trainer_interface.cc(592) LOG(INFO) Done! preprocessed 252777 sentences.
# trainer_interface.cc(598) LOG(INFO) Tokenizing input sentences with whitespace: 252777
# trainer_interface.cc(609) LOG(INFO) Done! 451676
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=784534 min_freq=48
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=230647 size=20 all=466920 active=24489 piece=▁p
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=133608 size=40 all=468001 active=25570 piece=le
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=76377 size=60 all=469308 active=26877 piece=▁that
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=53172 size=80 all=470797 active=28366 piece=▁st
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=41161 size=100 all=472201 active=29770 piece=ith
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=40896 min_freq=57
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=35285 size=120 all=473404 active=24769 piece=▁an
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=30714 size=140 all=474853 active=26218 piece=▁com
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=26099 size=160 all=480762 active=32127 piece=▁sh
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=23463 size=180 all=482081 active=33446 piece=ant
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=20813 size=200 all=484281 active=35646 piece=▁more
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=20789 min_freq=61
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=18262 size=220 all=487474 active=27404 piece=我们
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=16931 size=240 all=492352 active=32282 piece=all
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=15422 size=260 all=497661 active=37591 piece=问题
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=14325 size=280 all=500237 active=40167 piece=▁(
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=13292 size=300 all=503874 active=43804 piece=ks
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=13288 min_freq=62
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=12589 size=320 all=509307 active=30567 piece=one
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=11703 size=340 all=513439 active=34699 piece=lobal
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=10721 size=360 all=517110 active=38370 piece=主义
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=10176 size=380 all=522802 active=44062 piece=rad
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=9479 size=400 all=528921 active=50181 piece=ident
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=9471 min_freq=60
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=9092 size=420 all=529557 active=27056 piece=银行
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=8508 size=440 all=536514 active=34013 piece=▁such
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=8122 size=460 all=539136 active=36635 piece=▁qu
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=7824 size=480 all=541070 active=38569 piece=▁if
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=7518 size=500 all=545831 active=43330 piece=ach
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=7516 min_freq=58
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=7327 size=520 all=549506 active=30882 piece=▁cur
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=6880 size=540 all=553194 active=34570 piece=货币
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=6580 size=560 all=557532 active=38908 piece=▁trad
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=6436 size=580 all=559570 active=40946 piece=ating
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=6145 size=600 all=563949 active=45325 piece=尽管
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=6128 min_freq=57
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=5949 size=620 all=571056 active=34402 piece=▁Russ
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=5765 size=640 all=577147 active=40493 piece=ists
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=5668 size=660 all=583092 active=46438 piece=▁international
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=5513 size=680 all=590252 active=53598 piece=ient
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=5392 size=700 all=594757 active=58103 piece=情况
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=5388 min_freq=53
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=5183 size=720 all=602884 active=37243 piece=aw
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=5066 size=740 all=610441 active=44800 piece=imate
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=4937 size=760 all=614217 active=48576 piece=▁fact
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=4782 size=780 all=618412 active=52771 piece=round
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=4629 size=800 all=623628 active=57987 piece=term
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=4627 min_freq=50
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=4502 size=820 all=627318 active=34856 piece=▁On
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=4378 size=840 all=632721 active=40259 piece=pr
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=4283 size=860 all=639073 active=46611 piece=▁last
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=4205 size=880 all=644872 active=52410 piece=oun
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=4074 size=900 all=650262 active=57800 piece=rael
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=4074 min_freq=47
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=3994 size=920 all=654471 active=36716 piece=年的
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=3905 size=940 all=660950 active=43195 piece=▁hum
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=3830 size=960 all=665857 active=48102 piece=▁bank
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=3716 size=980 all=672639 active=54884 piece=▁does
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=3643 size=1000 all=683010 active=65255 piece=▁policies
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=3642 min_freq=45
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=3578 size=1020 all=687848 active=38989 piece=▁every
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=3516 size=1040 all=694533 active=45674 piece=以来
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=3449 size=1060 all=697212 active=48353 piece=iew
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=3394 size=1080 all=704767 active=55908 piece=▁benef
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=3325 size=1100 all=710816 active=61957 piece=公共
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=3322 min_freq=42
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=3287 size=1120 all=713945 active=38018 piece=idd
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=3242 size=1140 all=719098 active=43171 piece=他们的
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=3195 size=1160 all=725054 active=49127 piece=inc
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=3133 size=1180 all=730150 active=54223 piece=不能
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=3082 size=1200 all=737181 active=61254 piece=▁energy
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=3079 min_freq=40
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=3044 size=1220 all=746364 active=46043 piece=特朗
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=2997 size=1240 all=752139 active=51818 piece=▁threat
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=2967 size=1260 all=758585 active=58264 piece=使用
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=2927 size=1280 all=760606 active=60285 piece=ama
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=2887 size=1300 all=765773 active=65452 piece=▁product
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=2886 min_freq=38
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=2848 size=1320 all=773686 active=46198 piece=▁dire
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=2809 size=1340 all=778743 active=51255 piece=xt
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=2767 size=1360 all=783429 active=55941 piece=▁president
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=2724 size=1380 all=791166 active=63678 piece=▁To
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=2679 size=1400 all=797156 active=69668 piece=人口
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=2679 min_freq=36
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=2631 size=1420 all=803065 active=45089 piece=伊拉克
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=2598 size=1440 all=808210 active=50234 piece=▁view
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=2559 size=1460 all=813410 active=55434 piece=▁ful
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=2525 size=1480 all=816635 active=58659 piece=ructure
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=2493 size=1500 all=820942 active=62966 piece=▁increase
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=2492 min_freq=35
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=2470 size=1520 all=825701 active=45807 piece=ying
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=2450 size=1540 all=829356 active=49462 piece=▁mat
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=2418 size=1560 all=837968 active=58074 piece=▁though
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=2372 size=1580 all=844954 active=65060 piece=▁income
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=2337 size=1600 all=847625 active=67731 piece=援助
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=2337 min_freq=33
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=2310 size=1620 all=850892 active=44857 piece=pecially
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=2278 size=1640 all=855036 active=49001 piece=▁He
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=2255 size=1660 all=858668 active=52633 piece=破坏
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=2219 size=1680 all=864031 active=57996 piece=贷款
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=2190 size=1700 all=867699 active=61664 piece=idence
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=2189 min_freq=33
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=2160 size=1720 all=871416 active=47093 piece=中东
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=2121 size=1740 all=877176 active=52853 piece=的大
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=2106 size=1760 all=881116 active=56793 piece=for
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=2080 size=1780 all=886305 active=61982 piece=▁longer
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=2058 size=1800 all=890199 active=65876 piece=▁viol
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=2057 min_freq=32
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=2029 size=1820 all=896737 active=51037 piece=知道
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=2008 size=1840 all=904449 active=58749 piece=▁given
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=1991 size=1860 all=907764 active=62064 piece=贫困
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=1961 size=1880 all=911413 active=65713 piece=大量
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=1942 size=1900 all=915218 active=69518 piece=联储
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=1942 min_freq=30
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=1921 size=1920 all=920197 active=50339 piece=▁growing
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=1896 size=1940 all=924793 active=54935 piece=▁tru
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=1871 size=1960 all=929693 active=59835 piece=气候变化
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=1848 size=1980 all=934763 active=64905 piece=▁currency
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=1833 size=2000 all=937580 active=67722 piece=reng
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=1833 min_freq=29
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=1816 size=2020 all=942883 active=52175 piece=巨大的
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=1794 size=2040 all=946429 active=55721 piece=▁number
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=1771 size=2060 all=952569 active=61861 piece=▁never
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=1753 size=2080 all=956055 active=65347 piece=▁force
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=1736 size=2100 all=957794 active=67086 piece=▁What
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=1735 min_freq=29
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=1718 size=2120 all=962201 active=52296 piece=相对
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=1702 size=2140 all=967095 active=57190 piece=▁accept
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=1671 size=2160 all=971981 active=62076 piece=oura
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=1656 size=2180 all=974552 active=64647 piece=穆斯
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=1637 size=2200 all=979363 active=69458 piece=▁somet
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=1636 min_freq=28
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=1626 size=2220 all=982911 active=52514 piece=▁campaign
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=1612 size=2240 all=987310 active=56913 piece=gypt
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=1603 size=2260 all=990972 active=60575 piece=▁head
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=1580 size=2280 all=996813 active=66416 piece=▁ever
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=1567 size=2300 all=1001838 active=71441 piece=lation
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=1566 min_freq=27
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=1550 size=2320 all=1008083 active=56326 piece=▁dev
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=1534 size=2340 all=1014837 active=63080 piece=依赖
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=1520 size=2360 all=1020310 active=68553 piece=▁dou
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=1504 size=2380 all=1024362 active=72605 piece=融资
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=1485 size=2400 all=1029743 active=77986 piece=to
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=1483 min_freq=26
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=1470 size=2420 all=1032881 active=54583 piece=▁British
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=1458 size=2440 all=1039361 active=61063 piece=▁相反
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=1445 size=2460 all=1042778 active=64480 piece=incip
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=1431 size=2480 all=1045819 active=67521 piece=,“
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=1416 size=2500 all=1051408 active=73110 piece=积极
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=1416 min_freq=25
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=1402 size=2520 all=1057111 active=57707 piece=▁Russian
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=1393 size=2540 all=1061908 active=62504 piece=▁top
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=1380 size=2560 all=1065922 active=66518 piece=▁decade
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=1361 size=2580 all=1073208 active=73804 piece=去年
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=1347 size=2600 all=1077538 active=78134 piece=建设
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=1346 min_freq=24
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=1328 size=2620 all=1084554 active=60154 piece=▁tre
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=1318 size=2640 all=1086287 active=61887 piece=开发
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=1307 size=2660 all=1091477 active=67077 piece=往往
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=1295 size=2680 all=1095355 active=70955 piece=开放
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=1282 size=2700 all=1100104 active=75704 piece=ned
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=1282 min_freq=24
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=1272 size=2720 all=1103461 active=58339 piece=iveness
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=1256 size=2740 all=1108788 active=63666 piece=某种
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=1242 size=2760 all=1115018 active=69896 piece=ruption
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=1230 size=2780 all=1121663 active=76541 piece=感到
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=1218 size=2800 all=1128768 active=83646 piece=▁single
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=1218 min_freq=23
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=1208 size=2820 all=1131081 active=58751 piece=▁water
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=1200 size=2840 all=1134195 active=61865 piece=目的
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=1191 size=2860 all=1137722 active=65392 piece=▁structural
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=1180 size=2880 all=1140828 active=68498 piece=market
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=1171 size=2900 all=1144613 active=72283 piece=简单
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=1171 min_freq=22
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=1159 size=2920 all=1147288 active=59534 piece=▁counter
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=1149 size=2940 all=1150432 active=62678 piece=▁demonst
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=1137 size=2960 all=1153154 active=65400 piece=▁perhaps
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=1130 size=2980 all=1156055 active=68301 piece=思想
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=1120 size=3000 all=1158170 active=70416 piece=▁ask
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=1120 min_freq=22
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=1113 size=3020 all=1161290 active=61026 piece=▁shift
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=1102 size=3040 all=1168314 active=68050 piece=另一个
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=1092 size=3060 all=1171664 active=71400 piece=oviet
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=1083 size=3080 all=1176147 active=75883 piece=美国人
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=1072 size=3100 all=1180193 active=79929 piece=▁How
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=1072 min_freq=21
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=1061 size=3120 all=1184003 active=62816 piece=▁nearly
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=1053 size=3140 all=1187685 active=66498 piece=的信
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=1047 size=3160 all=1191439 active=70252 piece=供应
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=1040 size=3180 all=1195259 active=74072 piece=▁economists
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=1033 size=3200 all=1200602 active=79415 piece=▁bonds
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=1033 min_freq=21
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=1023 size=3220 all=1205234 active=64663 piece=▁comes
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=1015 size=3240 all=1208139 active=67568 piece=rugg
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=1006 size=3260 all=1210559 active=69988 piece=使得
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=999 size=3280 all=1213910 active=73339 piece=▁things
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=990 size=3300 all=1216563 active=75992 piece=基因
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=990 min_freq=20
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=986 size=3320 all=1220603 active=64404 piece=证据
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=980 size=3340 all=1223687 active=67488 piece=进口
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=973 size=3360 all=1229238 active=73039 piece=▁rat
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=963 size=3380 all=1232133 active=75934 piece=逐渐
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=953 size=3400 all=1235371 active=79172 piece=▁laun
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=953 min_freq=20
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=943 size=3420 all=1238182 active=64577 piece=都会
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=935 size=3440 all=1243093 active=69488 piece=▁发
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=926 size=3460 all=1248562 active=74957 piece=增长的
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=919 size=3480 all=1252273 active=78668 piece=▁mob
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=910 size=3500 all=1256339 active=82734 piece=观察
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=910 min_freq=20
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=904 size=3520 all=1260122 active=66219 piece=▁According
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=897 size=3540 all=1263192 active=69289 piece=▁mere
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=893 size=3560 all=1266234 active=72331 piece=arter
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=886 size=3580 all=1268708 active=74805 piece=leg
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=878 size=3600 all=1271222 active=77319 piece=▁confidence
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=877 min_freq=19
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=870 size=3620 all=1274339 active=66679 piece=▁cities
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=861 size=3640 all=1278668 active=71008 piece=▁defense
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=855 size=3660 all=1283015 active=75355 piece=▁Mexico
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=849 size=3680 all=1287842 active=80182 piece=▁above
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=842 size=3700 all=1289645 active=81985 piece=▁但这
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=842 min_freq=19
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=835 size=3720 all=1293419 active=68100 piece=团结
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=830 size=3740 all=1297316 active=71997 piece=年以来
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=824 size=3760 all=1301162 active=75843 piece=质量
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=819 size=3780 all=1307289 active=81970 piece=▁doubt
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=814 size=3800 all=1309831 active=84512 piece=▁dram
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=814 min_freq=18
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=809 size=3820 all=1314239 active=69896 piece=▁Although
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=802 size=3840 all=1317446 active=73103 piece=投入
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=797 size=3860 all=1322811 active=78468 piece=银行的
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=791 size=3880 all=1324991 active=80648 piece=共识
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=786 size=3900 all=1327955 active=83612 piece=有效的
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=786 min_freq=18
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=781 size=3920 all=1330745 active=68675 piece=▁family
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=774 size=3940 all=1334160 active=72090 piece=▁gradu
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=770 size=3960 all=1337606 active=75536 piece=▁special
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=766 size=3980 all=1341715 active=79645 piece=▁choice
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=759 size=4000 all=1346115 active=84045 piece=▁stimulus
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=758 min_freq=18
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=754 size=4020 all=1347791 active=68982 piece=loc
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=748 size=4040 all=1350898 active=72089 piece=▁thought
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=742 size=4060 all=1353127 active=74318 piece=更好
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=737 size=4080 all=1355567 active=76758 piece=▁Indian
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=732 size=4100 all=1358814 active=80005 piece=普通
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=732 min_freq=18
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=726 size=4120 all=1362923 active=71654 piece=pro
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=721 size=4140 all=1364388 active=73119 piece=主导
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=717 size=4160 all=1368612 active=77343 piece=phas
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=711 size=4180 all=1372749 active=81480 piece=hel
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=708 size=4200 all=1375362 active=84093 piece=▁technological
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=707 min_freq=17
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=704 size=4220 all=1380431 active=73838 piece=地球
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=699 size=4240 all=1383768 active=77175 piece=批准
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=693 size=4260 all=1387055 active=80462 piece=▁appears
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=689 size=4280 all=1388569 active=81976 piece=克尔
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=686 size=4300 all=1391156 active=84563 piece=民粹主义
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=686 min_freq=17
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=681 size=4320 all=1395337 active=73310 piece=民族主义
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=678 size=4340 all=1400017 active=77990 piece=▁terrorism
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=673 size=4360 all=1404424 active=82397 piece=▁人们
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=670 size=4380 all=1406444 active=84417 piece=▁housing
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=665 size=4400 all=1409581 active=87554 piece=边境
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=665 min_freq=17
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=661 size=4420 all=1411943 active=72440 piece=层面
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=658 size=4440 all=1414569 active=75066 piece=)、
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=654 size=4460 all=1417264 active=77761 piece=▁类似
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=650 size=4480 all=1419835 active=80332 piece=左翼
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=646 size=4500 all=1423265 active=83762 piece=答案
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=646 min_freq=16
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=643 size=4520 all=1427315 active=74982 piece=有利于
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=640 size=4540 all=1432093 active=79760 piece=war
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=637 size=4560 all=1434925 active=82592 piece=阿根
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=633 size=4580 all=1439756 active=87423 piece=going
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=628 size=4600 all=1443328 active=90995 piece=▁fix
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=628 min_freq=16
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=626 size=4620 all=1444776 active=73602 piece=▁seemed
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=623 size=4640 all=1449386 active=78212 piece=▁sides
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=619 size=4660 all=1453481 active=82307 piece=反对派
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=617 size=4680 all=1456504 active=85330 piece=▁conduct
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=614 size=4700 all=1459739 active=88565 piece=▁intellig
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=613 min_freq=16
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=610 size=4720 all=1462024 active=75268 piece=▁Korean
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=606 size=4740 all=1464792 active=78036 piece=ancial
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=602 size=4760 all=1466173 active=79417 piece=定义
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=599 size=4780 all=1468295 active=81539 piece=nic
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=597 size=4800 all=1471947 active=85191 piece=▁confront
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=596 min_freq=16
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=594 size=4820 all=1474956 active=76604 piece=▁oblig
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=591 size=4840 all=1477071 active=78719 piece=▁creditors
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=587 size=4860 all=1479235 active=80883 piece=机器
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=585 size=4880 all=1482354 active=84002 piece=▁story
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=581 size=4900 all=1484382 active=86030 piece=克服
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=581 min_freq=15
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=580 size=4920 all=1489286 active=78684 piece=▁expectations
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=576 size=4940 all=1492189 active=81587 piece=其它
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=574 size=4960 all=1496733 active=86131 piece=▁Go
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=571 size=4980 all=1499595 active=88993 piece=明智
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=569 size=5000 all=1501660 active=91058 piece=▁referendum
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=568 min_freq=15
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=566 size=5020 all=1505857 active=79280 piece=reaty
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=563 size=5040 all=1508616 active=82039 piece=安理会
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=560 size=5060 all=1512498 active=85921 piece=特别是在
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=556 size=5080 all=1515043 active=88466 piece=▁remark
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=552 size=5100 all=1519103 active=92526 piece=▁abroad
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=551 min_freq=15
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=549 size=5120 all=1521725 active=78578 piece=raft
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=546 size=5140 all=1524071 active=80924 piece=▁isol
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=544 size=5160 all=1526684 active=83537 piece=▁accounts
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=542 size=5180 all=1530890 active=87743 piece=▁specific
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=539 size=5200 all=1535399 active=92252 piece=动力
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=539 min_freq=15
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=537 size=5220 all=1537472 active=78553 piece=▁macroeconomic
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=535 size=5240 all=1540835 active=81916 piece=就可以
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=533 size=5260 all=1543313 active=84394 piece=▁trading
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=530 size=5280 all=1545623 active=86704 piece=操纵
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=528 size=5300 all=1549237 active=90318 piece=ossil
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=528 min_freq=15
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=525 size=5320 all=1553138 active=81358 piece=▁Keynes
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=522 size=5340 all=1554662 active=82882 piece=组织的
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=519 size=5360 all=1558705 active=86925 piece=ani
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=517 size=5380 all=1561348 active=89568 piece=▁secur
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=514 size=5400 all=1564401 active=92621 piece=愤怒
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=514 min_freq=14
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=512 size=5420 all=1567609 active=81152 piece=包含
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=509 size=5440 all=1571320 active=84863 piece=▁trial
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=506 size=5460 all=1574754 active=88297 piece=伊斯兰国
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=504 size=5480 all=1578409 active=91952 piece=一点
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=503 size=5500 all=1580167 active=93710 piece=▁giving
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=503 min_freq=14
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=501 size=5520 all=1582280 active=81122 piece=▁depends
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=499 size=5540 all=1584239 active=83081 piece=▁fell
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=497 size=5560 all=1585768 active=84610 piece=▁lies
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=495 size=5580 all=1587844 active=86686 piece=▁advance
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=493 size=5600 all=1591901 active=90743 piece=▁hit
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=493 min_freq=14
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=490 size=5620 all=1594435 active=82127 piece=拉丁
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=489 size=5640 all=1595674 active=83366 piece=▁populist
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=486 size=5660 all=1599192 active=86884 piece=结合
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=484 size=5680 all=1602500 active=90192 piece=▁remained
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=481 size=5700 all=1604061 active=91753 piece=▁acknow
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=481 min_freq=14
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=478 size=5720 all=1607259 active=83400 piece=uine
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=475 size=5740 all=1610146 active=86287 piece=▁generally
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=472 size=5760 all=1612502 active=88643 piece=共产主义
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=469 size=5780 all=1614835 active=90976 piece=做的
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=468 size=5800 all=1617019 active=93160 piece=▁partnership
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=467 min_freq=14
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=465 size=5820 all=1620703 active=84534 piece=cale
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=463 size=5840 all=1623622 active=87453 piece=▁upon
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=461 size=5860 all=1626560 active=90391 piece=营养
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=460 size=5880 all=1629320 active=93151 piece=iately
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=457 size=5900 all=1630995 active=94826 piece=ains
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=457 min_freq=14
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=455 size=5920 all=1632635 active=83168 piece=员工
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=452 size=5940 all=1636163 active=86696 piece=EN
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=450 size=5960 all=1637490 active=88023 piece=海洋
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=448 size=5980 all=1639644 active=90177 piece=▁Kremlin
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=446 size=6000 all=1642113 active=92646 piece=▁forms
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=446 min_freq=13
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=444 size=6020 all=1644883 active=84876 piece=uries
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=442 size=6040 all=1647959 active=87952 piece=▁过去
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=440 size=6060 all=1650262 active=90255 piece=持久
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=439 size=6080 all=1653307 active=93300 piece=▁lesson
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=437 size=6100 all=1655022 active=95015 piece=自动
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=437 min_freq=13
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=435 size=6120 all=1657762 active=85159 piece=万人
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=434 size=6140 all=1659690 active=87087 piece=任命
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=433 size=6160 all=1663694 active=91091 piece=▁pace
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=431 size=6180 all=1665058 active=92455 piece=Americ
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=429 size=6200 all=1668058 active=95455 piece=istics
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=429 min_freq=13
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=426 size=6220 all=1670652 active=85990 piece=迹象
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=425 size=6240 all=1673303 active=88641 piece=▁planet
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=423 size=6260 all=1675406 active=90744 piece=▁territory
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=421 size=6280 all=1677785 active=93123 piece=▁imbalances
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=418 size=6300 all=1679473 active=94811 piece=人数
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=418 min_freq=13
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=417 size=6320 all=1683808 active=88036 piece=▁medic
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=415 size=6340 all=1684913 active=89141 piece=上去
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=414 size=6360 all=1686648 active=90876 piece=▁protests
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=412 size=6380 all=1691254 active=95482 piece=▁Nob
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=411 size=6400 all=1694531 active=98759 piece=实现了

# %%
import subprocess
import os

result = subprocess.run('bash -c "source /etc/network_turbo && env | grep proxy"', shell=True, capture_output=True, text=True)
output = result.stdout
for line in output.splitlines():
    if '=' in line:
        var, value = line.split('=', 1)
        os.environ[var] = value
# Out:
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=411 min_freq=13
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=409 size=6420 all=1697434 active=87227 piece=身上
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=407 size=6440 all=1700109 active=89902 piece=声明
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=407 size=6460 all=1703393 active=93186 piece=▁resolve
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=405 size=6480 all=1706630 active=96423 piece=▁诚然
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=404 size=6500 all=1709336 active=99129 piece=▁truly
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=404 min_freq=13
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=402 size=6520 all=1711799 active=87930 piece=▁alloc
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=400 size=6540 all=1715059 active=91190 piece=▁bear
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=398 size=6560 all=1716602 active=92733 piece=违反
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=397 size=6580 all=1719445 active=95576 piece=▁believed
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=394 size=6600 all=1721673 active=97804 piece=ores
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=394 min_freq=13
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=392 size=6620 all=1723860 active=88248 piece=CS
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=391 size=6640 all=1726253 active=90641 piece=▁Communist
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=389 size=6660 all=1728549 active=92937 piece=南亚
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=388 size=6680 all=1732004 active=96392 piece=▁ready
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=386 size=6700 all=1733673 active=98061 piece=纳入
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=386 min_freq=12
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=384 size=6720 all=1737934 active=90590 piece=操作
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=383 size=6740 all=1740744 active=93400 piece=▁deprec
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=381 size=6760 all=1743143 active=95799 piece=本质
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=380 size=6780 all=1745807 active=98463 piece=不确定性
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=378 size=6800 all=1747791 active=100447 piece=密切
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=378 min_freq=12
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=377 size=6820 all=1751477 active=90845 piece=近期
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=376 size=6840 all=1753772 active=93140 piece=▁Venezuela
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=374 size=6860 all=1755165 active=94533 piece=▁perceived
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=372 size=6880 all=1758190 active=97558 piece=▁described
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=371 size=6900 all=1760292 active=99660 piece=▁determined
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=371 min_freq=12
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=370 size=6920 all=1763159 active=90881 piece=▁remind
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=369 size=6940 all=1764690 active=92412 piece=▁institution
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=367 size=6960 all=1767323 active=95045 piece=某种程度上
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=366 size=6980 all=1769950 active=97672 piece=▁online
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=364 size=7000 all=1772707 active=100429 piece=▁Bang
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=364 min_freq=12
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=363 size=7020 all=1774618 active=90542 piece=▁expanding
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=361 size=7040 all=1777789 active=93713 piece=美元的
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=359 size=7060 all=1780189 active=96113 piece=施加
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=358 size=7080 all=1782720 active=98644 piece=▁Palestine
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=356 size=7100 all=1784492 active=100416 piece=IDS
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=356 min_freq=12
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=355 size=7120 all=1786688 active=91418 piece=level
# trainer_interface.cc(687) LOG(INFO) Saving model: chinese_bpe.model
# trainer_interface.cc(699) LOG(INFO) Saving vocabs: chinese_bpe.vocab

# %%
cache_directory = "/root/autodl-tmp"

# 2. 加载 LLaMa 和中文词表
llama_tokenizer_dir = "./llama_tokenizer"  # LLaMa 模型的分词器路径
chinese_sp_model_file = "./chinese_bpe.model"  # 新训练的中文词表路径

# baichuan2是BPE分词的，LLama2也是，但是被墙了下不了，所以用baichuan2代替一下
llama_tokenizer = AutoTokenizer.from_pretrained('baichuan-inc/Baichuan2-7B-Chat', cache_dir=cache_directory)
chinese_sp_model = spm.SentencePieceProcessor()
chinese_sp_model.Load(chinese_sp_model_file)
# llama2这里被墙了 申请的时候不要写china
# Out:
# The repository for baichuan-inc/Baichuan2-7B-Chat contains custom code which must be executed to correctly load the model. You can inspect the repository content at https://hf.co/baichuan-inc/Baichuan2-7B-Chat.
# You can avoid this prompt in future by passing the argument `trust_remote_code=True`.
#
# Do you wish to run the custom code? [y/N]  y
# True

# %%
# 3. 解析 LLaMa 和中文词表的内部结构
llama_spm = sp_pb2_model.ModelProto()
llama_spm.ParseFromString(llama_tokenizer.sp_model.serialized_model_proto())

chinese_spm = sp_pb2_model.ModelProto()
chinese_spm.ParseFromString(chinese_sp_model.serialized_model_proto())

# 4. 打印两个词表的大小和特殊 token
print(f"LLaMa tokenizer size: {len(llama_tokenizer)}")
print(f"Chinese tokenizer size: {len(chinese_sp_model)}")
print("LLaMa special tokens:", llama_tokenizer.all_special_tokens)
print("LLaMa special token IDs:", llama_tokenizer.all_special_ids)
print("LLaMa special token map:", llama_tokenizer.special_tokens_map)
# Out:
# LLaMa tokenizer size: 125696
# Chinese tokenizer size: 10000
# LLaMa special tokens: ['<s>', '</s>', '<unk>']
# LLaMa special token IDs: [1, 2, 0]
# LLaMa special token map: {'bos_token': '<s>', 'eos_token': '</s>', 'unk_token': '<unk>', 'pad_token': '<unk>'}

# %%
# 5. 合并词表
llama_spm_tokens_set = set(p.piece for p in llama_spm.pieces)
print(f"Before: {len(llama_spm_tokens_set)}")

for p in chinese_spm.pieces:
    piece = p.piece
    if piece not in llama_spm_tokens_set:
        # print(1)
        new_p = sp_pb2_model.ModelProto().SentencePiece()
        new_p.piece = piece
        new_p.score = 0
        llama_spm.pieces.append(new_p)

print(f"New model pieces: {len(llama_spm.pieces)}")
# Out:
# Before: 125696
# New model pieces: 126211

# %%
# 6. 保存合并后的词表
from transformers import  LlamaTokenizer

output_sp_dir = 'merged_tokenizer_sp'
output_hf_dir = 'merged_tokenizer_hf'
os.makedirs(output_sp_dir, exist_ok=True)

with open(output_sp_dir + '/chinese_llama.model', 'wb') as f:
    f.write(llama_spm.SerializeToString())

tokenizer = LlamaTokenizer(vocab_file=output_sp_dir+'/chinese_llama.model')
tokenizer.save_pretrained(output_hf_dir)

print(f"Chinese-LLaMA tokenizer has been saved to {output_hf_dir}")
# Out:
# You are using the default legacy behaviour of the <class 'transformers.models.llama.tokenization_llama.LlamaTokenizer'>. This is expected, and simply means that the `legacy` (previous) behavior will be used so nothing changes for you. If you want to use the new behaviour, set `legacy=False`. This should only be set if you understand what it means, and thoroughly read the reason why this was added as explained in https://github.com/huggingface/transformers/pull/24565 - if you loaded a llama tokenizer from a GGUF file you can ignore this message
# Chinese-LLaMA tokenizer has been saved to merged_tokenizer_hf

# %%
# 7. 测试效果
text_en = "The excellence of a translation can only be judged by noting"
text_cn = "麒麟，是中国古代神话中的一种瑞兽"

print("Test English text:\n", text_en)
print(f"Tokenized by LLaMA tokenizer: {llama_tokenizer.tokenize(text_en)}")
print(f"Tokenized length by LLaMA tokenizer: {len(llama_tokenizer.tokenize(text_en))}")
print(f"Tokenized by Chinese-LLaMA tokenizer: {tokenizer.tokenize(text_en)}")
print(f"Tokenized length by Chinese-LLaMA tokenizer: {len(tokenizer.tokenize(text_en))}")

print("Test Chinese text:\n", text_cn)
print(f"Tokenized by LLaMA tokenizer: {llama_tokenizer.tokenize(text_cn)}")
print(f"Tokenized length by LLaMA tokenizer: {len(llama_tokenizer.tokenize(text_cn))}")
print(f"Tokenized by Chinese-LLaMA tokenizer: {tokenizer.tokenize(text_cn)}")
print(f"Tokenized length by Chinese-LLaMA tokenizer: {len(tokenizer.tokenize(text_cn))}")
# Out:
# Test English text:
#  The excellence of a translation can only be judged by noting
# Tokenized by LLaMA tokenizer: ['The', '▁excellence', '▁of', '▁a', '▁translation', '▁can', '▁only', '▁be', '▁judged', '▁by', '▁noting']
# Tokenized length by LLaMA tokenizer: 11
# Tokenized by Chinese-LLaMA tokenizer: ['The', '▁excellence', '▁of', '▁a', '▁translation', '▁can', '▁only', '▁be', '▁judged', '▁by', '▁noting']
# Tokenized length by Chinese-LLaMA tokenizer: 11
# Test Chinese text:
#  麒麟，是中国古代神话中的一种瑞兽
# Tokenized by LLaMA tokenizer: ['麒麟', '，', '是中国', '古代', '神话', '中', '的一种', '瑞', '兽']
# Tokenized length by LLaMA tokenizer: 9
# Tokenized by Chinese-LLaMA tokenizer: ['麒麟', '，', '是中国', '古代', '神话', '中', '的一种', '瑞', '兽']
# Tokenized length by Chinese-LLaMA tokenizer: 9

# %%
# 测试完成 可以直接使用了
tokenizer_hf = AutoTokenizer.from_pretrained(output_hf_dir)
# 输入文本
text = "这是一个测试句子。"

# 分词
tokens = tokenizer_hf.tokenize(text)
print("Tokens:", tokens)

# 将 tokens 转换为 token IDs
token_ids = tokenizer_hf.convert_tokens_to_ids(tokens)
print("Token IDs:", token_ids)

# 编码文本为输入 ID
encoded_input = tokenizer_hf.encode(text, add_special_tokens=True)
print("Encoded Input:", encoded_input)

# 解码回文本
decoded_text = tokenizer_hf.decode(encoded_input)
print("Decoded Text:", decoded_text)
# Out:
# Tokens: ['▁这是', '一个', '测试', '句子', '。']
# Token IDs: [125939, 1558, 4330, 13937, 66]
# Encoded Input: [1, 125939, 1558, 4330, 13937, 66]
# Decoded Text: <s> 这是一个测试句子。
